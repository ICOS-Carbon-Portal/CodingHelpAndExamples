# %% [markdown]
# # ICOS FLUXNET zarr — variable explorer
#
# Every variable one ICOS ecosystem site publishes, group by group, straight
# from the production store at `https://zarr.icos-cp.eu/icos-fluxnet.zarr` —
# including the provenance record and the 4-D METEOSENS profile variables that
# the quickstarts skip.
#
# | Group path | Time resolution | Key content |
# |---|---|---|
# | `SE-Svb/` (root) | Half-hourly | Met forcing, NEE, GPP, RECO, LE, H, soil scalars |
# | `SE-Svb/meteosens` | Half-hourly | METEOSENS 4-D profile vars `(time, r, h, v)` |
# | `SE-Svb/fluxnet_dd` | Daily | Same variables aggregated to daily |
# | `SE-Svb/fluxnet_mm` | Monthly | Monthly means |
# | `SE-Svb/fluxnet_ww` | Weekly | Weekly means |
# | `SE-Svb/fluxnet_yy` | Annual | Annual sums / means |
#
# *Advanced example — notebook 11 of the [sample series](README.md). Builds on
# notebook 04 (FLUXNET basics). No account or token needed.*

# %%
import json
import numpy as np
import zarr
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

STORE = "https://zarr.icos-cp.eu/icos-fluxnet.zarr"
SITE  = "SE-Svb"


def open_group(group: str):
    """Group-URL open — each group carries its own consolidated metadata, so
    this is one small request (never open the store ROOT for a single site;
    its index covers every site). Lazy: chunks move only when values are
    read, and the proxy records what we touch for the passport (last cell)."""
    return xr.open_zarr(f"{STORE}/{group}", consolidated=True)


# Structural view of the site: the same consolidated document lists the
# sub-groups and arrays without touching any data.
z = zarr.open_group(f"{STORE}/{SITE}", mode="r")   # URL works directly
print(f"zarr version : {zarr.__version__}")
print("Sub-groups :", sorted(z.group_keys()))
print("Root arrays:", len(list(z.array_keys())))

prov = json.loads(z.attrs["_provenance"])
print(f"\n── Provenance for {SITE} ──")
print(f"  Created      : {prov['created']}")
print(f"  Last updated : {prov['last_updated']}")
print(f"  Archive      : {prov['archive']}")
print(f"  Source DOI   : {prov['source_doi']}")
print(f"  Citation     : {prov['citation'][:120]}…")
print("  History      :")
for h in prov["history"]:
    print(f"    {h['timestamp']}  {h['action']:8s}  {h['archive']}")
# Out:
# zarr version : 3.3.0
# Sub-groups : ['fluxnet_dd', 'fluxnet_mm', 'fluxnet_ww', 'fluxnet_yy', 'meteosens']
# Root arrays: 820
#
# ── Provenance for SE-Svb ──
#   Created      : 2026-05-25T00:22:08Z
#   Last updated : 2026-05-25T00:22:08Z
#   Archive      : ICOSETC_SE-Svb_ARCHIVE_L2.zip
#   Source DOI   : https://hdl.handle.net/11676/0wBKUBmuyFX1RXRxFT_UmwKp
#   Citation     : Peichl, M., Nilsson, M., Larmanou, E., Smith, P., Marklund, P., De Simon, G., Lofvenius, P., Dignam, R., Holst, J., Mold…
#   History      :
#     2026-05-25T00:22:08Z  create    ICOSETC_SE-Svb_ARCHIVE_L2.zip

# %% [markdown]
# ## 0 · Dataset structure
#
# Open each group with xarray and inspect dimensions, coordinates, and variable counts.

# %%
# Open every aggregation group of the site — all lazy, one metadata request each.
ds_hh        = open_group(SITE)
ds_dd        = open_group(f"{SITE}/fluxnet_dd")
ds_mm        = open_group(f"{SITE}/fluxnet_mm")
ds_ww        = open_group(f"{SITE}/fluxnet_ww")
ds_yy        = open_group(f"{SITE}/fluxnet_yy")
ds_meteosens = (open_group(f"{SITE}/meteosens")
                if "meteosens" in z.group_keys() else None)

for label, ds in [("root (HH)", ds_hh), ("fluxnet_dd", ds_dd),
                  ("fluxnet_mm", ds_mm), ("fluxnet_ww", ds_ww),
                  ("fluxnet_yy", ds_yy)]:
    print(f"  {label:<14}  {len(ds.data_vars):4d} vars   dims={dict(ds.sizes)}")
if ds_meteosens is not None:
    print(f"  {'meteosens':<14}  {len(ds_meteosens.data_vars):4d} vars   "
          f"dims={dict(ds_meteosens.sizes)}")
# Out:
#   root (HH)        697 vars   dims={'time': 122736, 'ALB_1_1_level': 1, 'CO2_DRY_level': 8, 'D_SNOW_1_1_level': 1, 'FETCH_level': 4, 'G_level': 2, 'partition_method': 2, 'ustar_threshold': 2, 'nee_variant': 11, 'G_1_1_level': 1, 'G_2_1_level': 1, 'G_3_1_level': 1, 'G_4_1_level': 1, 'H2O_level': 8, 'corr_pct': 3, 'LW_IN_1_1_level': 1, 'LW_OUT_1_1_level': 1, 'NETRAD_1_1_level': 1, 'PA_1_1_level': 1, 'PPFD_BC_IN_10_1_level': 1, 'PPFD_BC_IN_11_1_level': 1, 'PPFD_BC_IN_12_1_level': 1, 'PPFD_BC_IN_13_1_level': 1, 'PPFD_BC_IN_14_1_level': 1, 'PPFD_BC_IN_15_1_level': 1, 'PPFD_BC_IN_16_1_level': 1, 'PPFD_BC_IN_17_1_level': 1, 'PPFD_BC_IN_18_1_level': 1, 'PPFD_BC_IN_19_1_level': 1, 'PPFD_BC_IN_1_1_level': 1, 'PPFD_BC_IN_20_1_level': 1, 'PPFD_BC_IN_21_1_level': 1, 'PPFD_BC_IN_22_1_level': 1, 'PPFD_BC_IN_23_1_level': 1, 'PPFD_BC_IN_2_1_level': 1, 'PPFD_BC_IN_3_1_level': 1, 'PPFD_BC_IN_4_1_level': 1, 'PPFD_BC_IN_5_1_level': 1, 'PPFD_BC_IN_6_1_level': 1, 'PPFD_BC_IN_7_1_level': 1, 'PPFD_BC_IN_8_1_level': 1, 'PPFD_BC_IN_9_1_level': 1, 'PPFD_DIF_1_1_level': 1, 'PPFD_IN_1_1_level': 2, 'PPFD_OUT_1_1_level': 1, 'P_1_1_level': 2, 'P_2_1_level': 1, 'RH_level': 2, 'RH_1_1_level': 1, 'RH_1_2_level': 1, 'RH_2_1_level': 1, 'SG_1_1_level': 1, 'SG_2_1_level': 1, 'SG_3_1_level': 1, 'SG_4_1_level': 1, 'soil_layer': 6, 'SWC_1_1_level': 1, 'SWC_1_2_level': 1, 'SWC_1_3_level': 1, 'SWC_1_4_level': 1, 'SWC_1_5_level': 1, 'SWC_2_1_level': 1, 'SWC_2_2_level': 1, 'SWC_2_3_level': 1, 'SWC_2_4_level': 1, 'SWC_2_5_level': 1, 'SWC_3_1_level': 1, 'SWC_3_2_level': 1, 'SWC_3_3_level': 1, 'SWC_3_4_level': 1, 'SWC_3_5_level': 1, 'SWC_4_1_level': 1, 'SWC_4_2_level': 1, 'SWC_4_3_level': 1, 'SWC_4_4_level': 1, 'SWC_obs_level': 5, 'SW_IN_1_1_level': 2, 'SW_IN_2_1_level': 1, 'SW_OUT_1_1_level': 1, 'TA_level': 9, 'TA_1_1_level': 2, 'TA_1_2_level': 2, 'TA_2_1_level': 1, 'TA_2_10_level': 1, 'TA_2_11_level': 1, 'TA_2_12_level': 1, 'TA_2_13_level': 1, 'TA_2_14_level': 1, 'TA_2_15_level': 1, 'TA_2_16_level': 1, 'TA_2_2_level': 1, 'TA_2_3_level': 1, 'TA_2_4_level': 1, 'TA_2_5_level': 1, 'TA_2_6_level': 1, 'TA_2_7_level': 1, 'TA_2_8_level': 1, 'TA_2_9_level': 1, 'TA_4_1_level': 1, 'TA_5_1_level': 1, 'TS_1_1_level': 1, 'TS_1_2_level': 1, 'TS_1_3_level': 1, 'TS_1_4_level': 1, 'TS_1_5_level': 1, 'TS_1_6_level': 1, 'TS_2_1_level': 1, 'TS_2_2_level': 1, 'TS_3_1_level': 1, 'TS_3_2_level': 1, 'TS_3_3_level': 1, 'TS_3_4_level': 1, 'TS_3_5_level': 1, 'TS_3_6_level': 1, 'TS_4_1_level': 1, 'TS_4_2_level': 1, 'TS_obs_level': 6, 'VPD_level': 2, 'VPD_1_1_level': 1, 'VPD_1_2_level': 1, 'VPD_2_1_level': 1, 'WTD_1_1_level': 1, 'WTD_2_1_level': 1, 'nv': 2}
#   fluxnet_dd       187 vars   dims={'time': 2557, 'partition_method': 2, 'ustar_threshold': 2, 'nee_variant': 11, 'corr_pct': 3, 'soil_layer': 6, 'nv': 2}
#   fluxnet_mm       185 vars   dims={'time': 84, 'partition_method': 2, 'ustar_threshold': 2, 'nee_variant': 11, 'corr_pct': 3, 'soil_layer': 6, 'nv': 2}
#   fluxnet_ww       185 vars   dims={'time': 364, 'partition_method': 2, 'ustar_threshold': 2, 'nee_variant': 11, 'corr_pct': 3, 'soil_layer': 6, 'nv': 2}
#   fluxnet_yy       182 vars   dims={'time': 7, 'partition_method': 2, 'ustar_threshold': 2, 'nee_variant': 11, 'corr_pct': 3, 'soil_layer': 6, 'nv': 2}
#   meteosens        356 vars   dims={'time': 122736, 'ALB_r': 1, 'ALB_h': 1, 'ALB_v': 1, 'CO2_DRY_level': 8, 'D_SNOW_r': 1, 'D_SNOW_h': 1, 'D_SNOW_v': 1, 'FETCH_level': 4, 'G_r': 4, 'G_h': 1, 'G_v': 1, 'partition_method': 2, 'ustar_threshold': 2, 'nee_variant': 11, 'G_obs_level': 2, 'H2O_level': 8, 'corr_pct': 3, 'LW_IN_r': 1, 'LW_IN_h': 1, 'LW_IN_v': 1, 'LW_OUT_r': 1, 'LW_OUT_h': 1, 'LW_OUT_v': 1, 'NETRAD_r': 1, 'NETRAD_h': 1, 'NETRAD_v': 1, 'P_r': 2, 'P_h': 1, 'P_v': 2, 'PA_r': 1, 'PA_h': 1, 'PA_v': 1, 'PPFD_BC_IN_r': 23, 'PPFD_BC_IN_h': 1, 'PPFD_BC_IN_v': 1, 'PPFD_DIF_r': 1, 'PPFD_DIF_h': 1, 'PPFD_DIF_v': 1, 'PPFD_IN_r': 1, 'PPFD_IN_h': 1, 'PPFD_IN_v': 2, 'PPFD_OUT_r': 1, 'PPFD_OUT_h': 1, 'PPFD_OUT_v': 1, 'RH_r': 2, 'RH_h': 2, 'RH_v': 1, 'RH_obs_level': 2, 'SG_r': 4, 'SG_h': 1, 'SG_v': 1, 'soil_layer': 6, 'SWC_obs_r': 4, 'SWC_obs_h': 5, 'SWC_obs_v': 1, 'SWC_obs2_level': 5, 'SW_IN_r': 2, 'SW_IN_h': 1, 'SW_IN_v': 2, 'SW_OUT_r': 1, 'SW_OUT_h': 1, 'SW_OUT_v': 1, 'TA_r': 5, 'TA_h': 16, 'TA_v': 2, 'TA_obs_level': 9, 'TS_obs_r': 4, 'TS_obs_h': 6, 'TS_obs_v': 1, 'TS_obs2_level': 6, 'VPD_r': 2, 'VPD_h': 2, 'VPD_v': 1, 'VPD_obs_level': 2, 'WTD_r': 2, 'WTD_h': 1, 'WTD_v': 1, 'nv': 2}

# %%
# Inspect the 3-D NEE variable (time × ustar_threshold × nee_variant)
print(ds_hh["NEE"])
print()
print("ustar_threshold labels:", ds_hh["NEE"].ustar_threshold.values)
print("nee_variant labels    :", ds_hh["NEE"].nee_variant.values)
# Out:
# <xarray.DataArray 'NEE' (time: 122736, ustar_threshold: 2, nee_variant: 11)> Size: 11MB
# dask.array<open_dataset-NEE, shape=(122736, 2, 11), dtype=float32, chunksize=(30684, 1, 6), chunktype=numpy.ndarray>
# Coordinates:
#   * time             (time) datetime64[ns] 982kB 2019-01-01 ... 2025-12-31T23...
#   * ustar_threshold  (ustar_threshold) <U3 24B 'CUT' 'VUT'
#   * nee_variant      (nee_variant) <U7 308B 'REF' 'USTAR50' ... 'p84' 'p95'
# Attributes:
#     ancillary_variables:  NEE_QC
#     comment:              ustar_threshold: CUT = constant, VUT = variable. ne...
#     long_name:            Net Ecosystem Exchange
#     units:                umol m-2 s-1
#
# ustar_threshold labels: ['CUT' 'VUT']
# nee_variant labels    : ['REF' 'USTAR50' 'MEAN' 'SE' 'p05' 'p16' 'p25' 'p50' 'p75' 'p84' 'p95']

# %% [markdown]
# ## 1 · Half-hourly meteorology (root group)
#
# Air temperature and incoming shortwave radiation using xarray label-based indexing.

# %%
def _ylabel(da):
    ln = da.attrs.get("long_name", da.name or "")
    u  = da.attrs.get("units", "")
    return f"{ln}\n({u})" if u else ln

site_id = ds_hh.attrs.get("site_id", SITE)

da_ta    = ds_hh["TA_F"]
da_sw_in = ds_hh["SW_IN_F"]
ta    = da_ta.values.astype(float)
sw_in = da_sw_in.values.astype(float)
t_hh  = ds_hh["time"].values

fig, axes = plt.subplots(2, 1, figsize=(14, 6), sharex=True)
fig.suptitle(f"{site_id} — Half-hourly meteorology (root group)", fontweight="bold")

axes[0].plot(t_hh, ta, lw=0.4, color="tab:red")
axes[0].set_ylabel(_ylabel(da_ta))
axes[0].axhline(0, color="k", lw=0.5, ls="--")

axes[1].plot(t_hh, sw_in, lw=0.4, color="goldenrod")
axes[1].set_ylabel(_ylabel(da_sw_in))

for ax in axes:
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
    ax.grid(alpha=0.3)

fig.autofmt_xdate()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2 · Daily carbon fluxes (`fluxnet_dd`)
#
# **Top** — NEE with joint uncertainty envelope (VUT threshold, REF variant), using xarray `.sel()`.
# **Bottom** — GPP and RECO from both partitioning methods (NT = night-time, DT = day-time).

# %%
t_dd = ds_dd["time"].values

nee     = ds_dd["NEE"].sel(ustar_threshold="VUT", nee_variant="REF").values.astype(float)
nee_unc = ds_dd["NEE_JOINTUNC"].sel(ustar_threshold="VUT", nee_variant="REF").values.astype(float)
gpp_nt  = ds_dd["GPP"].sel(ustar_threshold="VUT", partition_method="NT", nee_variant="REF").values.astype(float)
gpp_dt  = ds_dd["GPP"].sel(ustar_threshold="VUT", partition_method="DT", nee_variant="REF").values.astype(float)
reco_nt = ds_dd["RECO"].sel(ustar_threshold="VUT", partition_method="NT", nee_variant="REF").values.astype(float)
reco_dt = ds_dd["RECO"].sel(ustar_threshold="VUT", partition_method="DT", nee_variant="REF").values.astype(float)

nee_ln    = ds_dd["NEE"].attrs.get("long_name", "NEE")
gpp_ln    = ds_dd["GPP"].attrs.get("long_name", "GPP")
reco_ln   = ds_dd["RECO"].attrs.get("long_name", "RECO")
nee_units = ds_dd["NEE"].attrs.get("units", "")

fig, axes = plt.subplots(2, 1, figsize=(14, 7), sharex=True)
fig.suptitle(f"{site_id} — Daily carbon fluxes (fluxnet_dd, VUT threshold, REF variant)",
             fontweight="bold")

ax = axes[0]
ax.fill_between(t_dd, nee - nee_unc, nee + nee_unc, alpha=0.25, color="tab:blue", label="Joint unc.")
ax.plot(t_dd, nee, lw=1, color="tab:blue", label="NEE VUT REF")
ax.axhline(0, color="k", lw=0.6, ls="--")
ax.set_ylabel(f"{nee_ln}\n({nee_units})" if nee_units else nee_ln)
ax.legend(fontsize=8)

ax = axes[1]
ax.plot(t_dd, gpp_nt,  lw=1, color="tab:green", label=f"{gpp_ln} NT")
ax.plot(t_dd, gpp_dt,  lw=1, color="limegreen",  label=f"{gpp_ln} DT", ls="--")
ax.plot(t_dd, reco_nt, lw=1, color="tab:brown",  label=f"{reco_ln} NT")
ax.plot(t_dd, reco_dt, lw=1, color="peru",        label=f"{reco_ln} DT", ls="--")
ax.set_ylabel(f"{gpp_ln} / {reco_ln}\n({nee_units})" if nee_units else f"{gpp_ln} / {reco_ln}")
ax.legend(fontsize=8, ncol=2)

for ax in axes:
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
    ax.grid(alpha=0.3)

fig.autofmt_xdate()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 3 · Monthly energy balance & soil profiles (`fluxnet_mm`)
#
# **Top** — Latent heat (LE) and sensible heat (H) at the median energy-balance correction (p50).
# **Bottom** — Soil temperature and soil water content profiles across all measured layers.

# %%
t_mm = ds_mm["time"].values

da_le  = ds_mm["LE_CORR"]
da_h   = ds_mm["H_CORR"]
da_ts  = ds_mm["TS"]
da_swc = ds_mm["SWC"]

le = da_le.sel(corr_pct="p50").values.astype(float)
h  = da_h.sel(corr_pct="p50").values.astype(float)

ts_all      = da_ts.values.astype(float)
swc_all     = da_swc.values.astype(float)
soil_labels = da_ts.soil_layer.values

le_ln   = da_le.attrs.get("long_name", "Latent heat flux")
h_ln    = da_h.attrs.get("long_name", "Sensible heat flux")
e_units = da_le.attrs.get("units", "W m-2")
ts_ln   = da_ts.attrs.get("long_name", "Soil temperature")
ts_u    = da_ts.attrs.get("units", "degC")
swc_ln  = da_swc.attrs.get("long_name", "SWC")
swc_u   = da_swc.attrs.get("units", "%")

fig, axes = plt.subplots(2, 1, figsize=(14, 7), sharex=True)
fig.suptitle(f"{site_id} — Monthly energy balance & soil profiles (fluxnet_mm)", fontweight="bold")

ax = axes[0]
ax.plot(t_mm, le, lw=1.5, color="tab:cyan",   label=f"{le_ln} (p50 EBC)")
ax.plot(t_mm, h,  lw=1.5, color="tab:orange", label=f"{h_ln} (p50 EBC)")
ax.axhline(0, color="k", lw=0.5, ls="--")
ax.set_ylabel(f"Energy flux\n({e_units})")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

ax = axes[1]
n_ts  = ts_all.shape[1]
n_swc = swc_all.shape[1]
cmap_ts  = plt.get_cmap("YlOrRd", max(n_ts,  2))
cmap_swc = plt.get_cmap("Blues",  max(n_swc, 3))
for i in range(n_ts):
    ax.plot(t_mm, ts_all[:, i],  lw=1, color=cmap_ts(i / max(n_ts - 1, 1)),
            label=f"TS {soil_labels[i]}")
for i in range(n_swc):
    ax.plot(t_mm, swc_all[:, i], lw=1, color=cmap_swc(0.4 + 0.6 * i / max(n_swc - 1, 1)),
            ls="--", label=f"SWC {soil_labels[i]}")
ax.set_ylabel(f"{ts_ln} ({ts_u})\n{swc_ln} ({swc_u})")
ax.legend(fontsize=7, ncol=4)
ax.grid(alpha=0.3)

for ax in axes:
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))

fig.autofmt_xdate()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 4 · Annual carbon budget (`fluxnet_yy`)
#
# Bar chart of annual NEE, GPP, and RECO (VUT threshold, REF variant, NT partitioning).
# Negative NEE = net carbon uptake (sink); positive = source.

# %%
t_yy  = ds_yy["time"].values
years = t_yy.astype("datetime64[Y]").astype(int) + 1970

da_nee  = ds_yy["NEE"]
da_gpp  = ds_yy["GPP"]
da_reco = ds_yy["RECO"]

nee_y  = da_nee.sel(ustar_threshold="VUT", nee_variant="REF").values.astype(float)
gpp_y  = da_gpp.sel(ustar_threshold="VUT", partition_method="NT", nee_variant="REF").values.astype(float)
reco_y = da_reco.sel(ustar_threshold="VUT", partition_method="NT", nee_variant="REF").values.astype(float)

nee_ln  = da_nee.attrs.get("long_name",  "NEE")
gpp_ln  = da_gpp.attrs.get("long_name",  "GPP")
reco_ln = da_reco.attrs.get("long_name", "RECO")
units   = da_nee.attrs.get("units", "")

x = np.arange(len(years))
w = 0.25

fig, ax = plt.subplots(figsize=(10, 5))
fig.suptitle(f"{site_id} — Annual carbon budget (fluxnet_yy, VUT REF, NT partitioning)",
             fontweight="bold")

ax.bar(x - w, nee_y,  w, label=nee_ln,  color="tab:blue",  alpha=0.85)
ax.bar(x,     gpp_y,  w, label=gpp_ln,  color="tab:green", alpha=0.85)
ax.bar(x + w, reco_y, w, label=reco_ln, color="tab:brown", alpha=0.85)
ax.axhline(0, color="k", lw=0.8)
ax.set_xticks(x)
ax.set_xticklabels(years)
ax.set_ylabel(f"({units})" if units else "")
ax.legend()
ax.grid(axis="y", alpha=0.3)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## 5 · METEOSENS 4-D profile variables (`meteosens` sub-group)
#
# METEOSENS profile variables (e.g. `TA`, `LW_IN`, `SWC`) live in the `meteosens` sub-group
# with dimensions `(time, r, h, v)` — repeat/replicate, height, vertical position.
# Plot monthly means for each (r, h, v) combination that has valid data.

# %%
if ds_meteosens is None:
    print("No meteosens sub-group found in this store.")
elif "TA" not in ds_meteosens:
    print("TA not found in meteosens group. Available vars:", list(ds_meteosens.data_vars))
else:
    ta4d = ds_meteosens["TA"]   # DataArray (time, TA_r, TA_h, TA_v)
    print("TA shape :", ta4d.shape)
    print("TA dims  :", ta4d.dims)

    # Resample to monthly means, then plot one line per (r,h,v) combo with valid data
    ta_monthly = ta4d.resample(time="ME").mean()

    r_vals = ta4d.coords[ta4d.dims[1]].values
    h_vals = ta4d.coords[ta4d.dims[2]].values
    v_vals = ta4d.coords[ta4d.dims[3]].values
    t_mo   = ta_monthly.time.values

    fig, ax = plt.subplots(figsize=(14, 5))
    fig.suptitle(f"{site_id} — Monthly mean air temperature by METEOSENS position (TA)",
                 fontweight="bold")

    n_plotted = 0
    for ri, r in enumerate(r_vals):
        for hi, h in enumerate(h_vals):
            for vi, v in enumerate(v_vals):
                col = ta_monthly.isel(**{ta4d.dims[1]: ri,
                                         ta4d.dims[2]: hi,
                                         ta4d.dims[3]: vi}).values.astype(float)
                if np.all(np.isnan(col)):
                    continue
                ax.plot(t_mo, col, lw=1, alpha=0.7, label=f"r={r} h={h} v={v}")
                n_plotted += 1

    print(f"  Plotted {n_plotted} non-empty (r, h, v) combination(s)")
    ta_units = ta4d.attrs.get("units", "")
    ta_ln    = ta4d.attrs.get("long_name", "Air temperature")
    ax.set_ylabel(f"{ta_ln}\n({ta_units})" if ta_units else ta_ln)
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
    ax.legend(fontsize=7, ncol=4, loc="upper right")
    ax.grid(alpha=0.3)
    fig.autofmt_xdate()
    fig.tight_layout()
    plt.show()
# Out:
# TA shape : (122736, 5, 16, 2)
# TA dims  : ('time', 'TA_r', 'TA_h', 'TA_v')
#   Plotted 22 non-empty (r, h, v) combination(s)

# %% [markdown]
# ## 6 · Store summary — all variables and their shapes

# %%
groups = [("root (HH)", ds_hh), ("fluxnet_dd", ds_dd),
          ("fluxnet_mm", ds_mm), ("fluxnet_ww", ds_ww), ("fluxnet_yy", ds_yy)]
if ds_meteosens is not None:
    groups.append(("meteosens", ds_meteosens))

for label, ds in groups:
    nd = sum(1 for v in ds.data_vars if len(ds[v].dims) > 1)
    n1 = sum(1 for v in ds.data_vars if len(ds[v].dims) == 1)
    print(f"\n{'─'*60}")
    print(f"  {label}   ({nd} multi-dim, {n1} 1-D)")
    print(f"{'─'*60}")
    # multi-dim first, then 1-D, sorted
    for vname in sorted(ds.data_vars, key=lambda v: (-len(ds[v].dims), v)):
        da = ds[vname]
        units = da.attrs.get("units", "")
        print(f"  {vname:<30s}  {str(da.dims):<55s}  {str(da.shape):<25s}  {units}")
# Out:
# ────────────────────────────────────────────────────────────
#   root (HH)   (448 multi-dim, 248 1-D)
# ────────────────────────────────────────────────────────────
#   GPP                             ('time', 'partition_method', 'ustar_threshold', 'nee_variant')  (122736, 2, 2, 11)         umol m-2 s-1
#   RECO                            ('time', 'partition_method', 'ustar_threshold', 'nee_variant')  (122736, 2, 2, 11)         umol m-2 s-1
#   NEE                             ('time', 'ustar_threshold', 'nee_variant')               (122736, 2, 11)            umol m-2 s-1
#   NEE_JOINTUNC                    ('time', 'ustar_threshold', 'nee_variant')               (122736, 2, 11)            umol m-2 s-1
#   NEE_QC                          ('time', 'ustar_threshold', 'nee_variant')               (122736, 2, 11)            1
#   NEE_RANDUNC                     ('time', 'ustar_threshold', 'nee_variant')               (122736, 2, 11)            umol m-2 s-1
#   ALB_1_1                         ('time', 'ALB_1_1_level')                                (122736, 1)                1
#   ALB_1_1_N                       ('time', 'ALB_1_1_level')                                (122736, 1)                1
#   CO2_DRY                         ('time', 'CO2_DRY_level')                                (122736, 8)                umol mol-1
#   CO2_DRY_SE                      ('time', 'CO2_DRY_level')                                (122736, 8)                umol mol-1
#   D_SNOW_1_1                      ('time', 'D_SNOW_1_1_level')                             (122736, 1)                1
#   D_SNOW_1_1_N                    ('time', 'D_SNOW_1_1_level')                             (122736, 1)                1
#   D_SNOW_1_1_QC                   ('time', 'D_SNOW_1_1_level')                             (122736, 1)                1
#   D_SNOW_1_1_SE                   ('time', 'D_SNOW_1_1_level')                             (122736, 1)                1
#   FETCH                           ('time', 'FETCH_level')                                  (122736, 4)                1
#   G                               ('time', 'G_level')                                      (122736, 2)                W m-2
#   G_1_1                           ('time', 'G_1_1_level')                                  (122736, 1)                W m-2
#   G_1_1_N                         ('time', 'G_1_1_level')                                  (122736, 1)                1
#   G_1_1_QC                        ('time', 'G_1_1_level')                                  (122736, 1)                1
#   G_1_1_SE                        ('time', 'G_1_1_level')                                  (122736, 1)                W m-2
#   G_2_1                           ('time', 'G_2_1_level')                                  (122736, 1)                W m-2
#   G_2_1_N                         ('time', 'G_2_1_level')                                  (122736, 1)                1
#   G_2_1_QC                        ('time', 'G_2_1_level')                                  (122736, 1)                1
#   G_2_1_SE                        ('time', 'G_2_1_level')                                  (122736, 1)                W m-2
#   G_3_1                           ('time', 'G_3_1_level')                                  (122736, 1)                W m-2
#   G_3_1_N                         ('time', 'G_3_1_level')                                  (122736, 1)                1
#   G_3_1_QC                        ('time', 'G_3_1_level')                                  (122736, 1)                1
#   G_3_1_SE                        ('time', 'G_3_1_level')                                  (122736, 1)                W m-2
#   G_4_1                           ('time', 'G_4_1_level')                                  (122736, 1)                W m-2
#   G_4_1_N                         ('time', 'G_4_1_level')                                  (122736, 1)                1
#   G_4_1_QC                        ('time', 'G_4_1_level')                                  (122736, 1)                1
#   G_4_1_SE                        ('time', 'G_4_1_level')                                  (122736, 1)                W m-2
#   G_N                             ('time', 'G_level')                                      (122736, 2)                1
#   G_SD                            ('time', 'G_level')                                      (122736, 2)                W m-2
#   H2O                             ('time', 'H2O_level')                                    (122736, 8)                mmol mol-1
#   H2O_SE                          ('time', 'H2O_level')                                    (122736, 8)                mmol mol-1
#   H_CORR                          ('time', 'corr_pct')                                     (122736, 3)                W m-2
#   LE_CORR                         ('time', 'corr_pct')                                     (122736, 3)                W m-2
#   LW_IN_1_1                       ('time', 'LW_IN_1_1_level')                              (122736, 1)                W m-2
#   LW_IN_1_1_N                     ('time', 'LW_IN_1_1_level')                              (122736, 1)                1
#   LW_IN_1_1_QC                    ('time', 'LW_IN_1_1_level')                              (122736, 1)                1
#   LW_IN_1_1_SE                    ('time', 'LW_IN_1_1_level')                              (122736, 1)                W m-2
#   LW_OUT_1_1                      ('time', 'LW_OUT_1_1_level')                             (122736, 1)                W m-2
#   LW_OUT_1_1_N                    ('time', 'LW_OUT_1_1_level')                             (122736, 1)                1
#   LW_OUT_1_1_QC                   ('time', 'LW_OUT_1_1_level')                             (122736, 1)                1
#   LW_OUT_1_1_SE                   ('time', 'LW_OUT_1_1_level')                             (122736, 1)                W m-2
#   NETRAD_1_1                      ('time', 'NETRAD_1_1_level')                             (122736, 1)                W m-2
#   NETRAD_1_1_N                    ('time', 'NETRAD_1_1_level')                             (122736, 1)                1
#   PA_1_1                          ('time', 'PA_1_1_level')                                 (122736, 1)                kPa
#   PA_1_1_N                        ('time', 'PA_1_1_level')                                 (122736, 1)                1
#   PA_1_1_QC                       ('time', 'PA_1_1_level')                                 (122736, 1)                1
#   PA_1_1_SE                       ('time', 'PA_1_1_level')                                 (122736, 1)                kPa
#   PPFD_BC_IN_10_1                 ('time', 'PPFD_BC_IN_10_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_10_1_N               ('time', 'PPFD_BC_IN_10_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_10_1_QC              ('time', 'PPFD_BC_IN_10_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_10_1_SE              ('time', 'PPFD_BC_IN_10_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_11_1                 ('time', 'PPFD_BC_IN_11_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_11_1_N               ('time', 'PPFD_BC_IN_11_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_11_1_QC              ('time', 'PPFD_BC_IN_11_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_11_1_SE              ('time', 'PPFD_BC_IN_11_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_12_1                 ('time', 'PPFD_BC_IN_12_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_12_1_N               ('time', 'PPFD_BC_IN_12_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_12_1_QC              ('time', 'PPFD_BC_IN_12_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_12_1_SE              ('time', 'PPFD_BC_IN_12_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_13_1                 ('time', 'PPFD_BC_IN_13_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_13_1_N               ('time', 'PPFD_BC_IN_13_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_13_1_QC              ('time', 'PPFD_BC_IN_13_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_13_1_SE              ('time', 'PPFD_BC_IN_13_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_14_1                 ('time', 'PPFD_BC_IN_14_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_14_1_N               ('time', 'PPFD_BC_IN_14_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_14_1_QC              ('time', 'PPFD_BC_IN_14_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_14_1_SE              ('time', 'PPFD_BC_IN_14_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_15_1                 ('time', 'PPFD_BC_IN_15_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_15_1_N               ('time', 'PPFD_BC_IN_15_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_15_1_QC              ('time', 'PPFD_BC_IN_15_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_15_1_SE              ('time', 'PPFD_BC_IN_15_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_16_1                 ('time', 'PPFD_BC_IN_16_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_16_1_N               ('time', 'PPFD_BC_IN_16_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_16_1_QC              ('time', 'PPFD_BC_IN_16_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_16_1_SE              ('time', 'PPFD_BC_IN_16_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_17_1                 ('time', 'PPFD_BC_IN_17_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_17_1_N               ('time', 'PPFD_BC_IN_17_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_17_1_QC              ('time', 'PPFD_BC_IN_17_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_17_1_SE              ('time', 'PPFD_BC_IN_17_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_18_1                 ('time', 'PPFD_BC_IN_18_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_18_1_N               ('time', 'PPFD_BC_IN_18_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_18_1_QC              ('time', 'PPFD_BC_IN_18_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_18_1_SE              ('time', 'PPFD_BC_IN_18_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_19_1                 ('time', 'PPFD_BC_IN_19_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_19_1_N               ('time', 'PPFD_BC_IN_19_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_19_1_QC              ('time', 'PPFD_BC_IN_19_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_19_1_SE              ('time', 'PPFD_BC_IN_19_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_1_1                  ('time', 'PPFD_BC_IN_1_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_1_1_N                ('time', 'PPFD_BC_IN_1_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_1_1_QC               ('time', 'PPFD_BC_IN_1_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_1_1_SE               ('time', 'PPFD_BC_IN_1_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_20_1                 ('time', 'PPFD_BC_IN_20_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_20_1_N               ('time', 'PPFD_BC_IN_20_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_20_1_QC              ('time', 'PPFD_BC_IN_20_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_20_1_SE              ('time', 'PPFD_BC_IN_20_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_21_1                 ('time', 'PPFD_BC_IN_21_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_21_1_N               ('time', 'PPFD_BC_IN_21_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_21_1_QC              ('time', 'PPFD_BC_IN_21_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_21_1_SE              ('time', 'PPFD_BC_IN_21_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_22_1                 ('time', 'PPFD_BC_IN_22_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_22_1_N               ('time', 'PPFD_BC_IN_22_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_22_1_QC              ('time', 'PPFD_BC_IN_22_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_22_1_SE              ('time', 'PPFD_BC_IN_22_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_23_1                 ('time', 'PPFD_BC_IN_23_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_23_1_N               ('time', 'PPFD_BC_IN_23_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_23_1_QC              ('time', 'PPFD_BC_IN_23_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_23_1_SE              ('time', 'PPFD_BC_IN_23_1_level')                        (122736, 1)                1
#   PPFD_BC_IN_2_1                  ('time', 'PPFD_BC_IN_2_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_2_1_N                ('time', 'PPFD_BC_IN_2_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_2_1_QC               ('time', 'PPFD_BC_IN_2_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_2_1_SE               ('time', 'PPFD_BC_IN_2_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_3_1                  ('time', 'PPFD_BC_IN_3_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_3_1_N                ('time', 'PPFD_BC_IN_3_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_3_1_QC               ('time', 'PPFD_BC_IN_3_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_3_1_SE               ('time', 'PPFD_BC_IN_3_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_4_1                  ('time', 'PPFD_BC_IN_4_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_4_1_N                ('time', 'PPFD_BC_IN_4_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_4_1_QC               ('time', 'PPFD_BC_IN_4_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_4_1_SE               ('time', 'PPFD_BC_IN_4_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_5_1                  ('time', 'PPFD_BC_IN_5_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_5_1_N                ('time', 'PPFD_BC_IN_5_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_5_1_QC               ('time', 'PPFD_BC_IN_5_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_5_1_SE               ('time', 'PPFD_BC_IN_5_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_6_1                  ('time', 'PPFD_BC_IN_6_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_6_1_N                ('time', 'PPFD_BC_IN_6_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_6_1_QC               ('time', 'PPFD_BC_IN_6_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_6_1_SE               ('time', 'PPFD_BC_IN_6_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_7_1                  ('time', 'PPFD_BC_IN_7_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_7_1_N                ('time', 'PPFD_BC_IN_7_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_7_1_QC               ('time', 'PPFD_BC_IN_7_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_7_1_SE               ('time', 'PPFD_BC_IN_7_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_8_1                  ('time', 'PPFD_BC_IN_8_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_8_1_N                ('time', 'PPFD_BC_IN_8_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_8_1_QC               ('time', 'PPFD_BC_IN_8_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_8_1_SE               ('time', 'PPFD_BC_IN_8_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_9_1                  ('time', 'PPFD_BC_IN_9_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_9_1_N                ('time', 'PPFD_BC_IN_9_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_9_1_QC               ('time', 'PPFD_BC_IN_9_1_level')                         (122736, 1)                1
#   PPFD_BC_IN_9_1_SE               ('time', 'PPFD_BC_IN_9_1_level')                         (122736, 1)                1
#   PPFD_DIF_1_1                    ('time', 'PPFD_DIF_1_1_level')                           (122736, 1)                umol m-2 s-1
#   PPFD_DIF_1_1_N                  ('time', 'PPFD_DIF_1_1_level')                           (122736, 1)                1
#   PPFD_DIF_1_1_QC                 ('time', 'PPFD_DIF_1_1_level')                           (122736, 1)                1
#   PPFD_DIF_1_1_SE                 ('time', 'PPFD_DIF_1_1_level')                           (122736, 1)                umol m-2 s-1
#   PPFD_IN_1_1                     ('time', 'PPFD_IN_1_1_level')                            (122736, 2)                umol m-2 s-1
#   PPFD_IN_1_1_N                   ('time', 'PPFD_IN_1_1_level')                            (122736, 2)                1
#   PPFD_IN_1_1_QC                  ('time', 'PPFD_IN_1_1_level')                            (122736, 2)                1
#   PPFD_IN_1_1_SE                  ('time', 'PPFD_IN_1_1_level')                            (122736, 2)                umol m-2 s-1
#   PPFD_OUT_1_1                    ('time', 'PPFD_OUT_1_1_level')                           (122736, 1)                umol m-2 s-1
#   PPFD_OUT_1_1_N                  ('time', 'PPFD_OUT_1_1_level')                           (122736, 1)                1
#   PPFD_OUT_1_1_QC                 ('time', 'PPFD_OUT_1_1_level')                           (122736, 1)                1
#   PPFD_OUT_1_1_SE                 ('time', 'PPFD_OUT_1_1_level')                           (122736, 1)                umol m-2 s-1
#   P_1_1                           ('time', 'P_1_1_level')                                  (122736, 2)                mm
#   P_1_1_N                         ('time', 'P_1_1_level')                                  (122736, 2)                1
#   P_1_1_QC                        ('time', 'P_1_1_level')                                  (122736, 2)                1
#   P_1_1_SE                        ('time', 'P_1_1_level')                                  (122736, 2)                mm
#   P_2_1                           ('time', 'P_2_1_level')                                  (122736, 1)                mm
#   P_2_1_N                         ('time', 'P_2_1_level')                                  (122736, 1)                1
#   P_2_1_QC                        ('time', 'P_2_1_level')                                  (122736, 1)                1
#   P_2_1_SE                        ('time', 'P_2_1_level')                                  (122736, 1)                mm
#   RH                              ('time', 'RH_level')                                     (122736, 2)                %
#   RH_1_1                          ('time', 'RH_1_1_level')                                 (122736, 1)                %
#   RH_1_1_N                        ('time', 'RH_1_1_level')                                 (122736, 1)                1
#   RH_1_1_QC                       ('time', 'RH_1_1_level')                                 (122736, 1)                1
#   RH_1_1_SE                       ('time', 'RH_1_1_level')                                 (122736, 1)                %
#   RH_1_2                          ('time', 'RH_1_2_level')                                 (122736, 1)                %
#   RH_1_2_N                        ('time', 'RH_1_2_level')                                 (122736, 1)                1
#   RH_1_2_QC                       ('time', 'RH_1_2_level')                                 (122736, 1)                1
#   RH_1_2_SE                       ('time', 'RH_1_2_level')                                 (122736, 1)                %
#   RH_2_1                          ('time', 'RH_2_1_level')                                 (122736, 1)                %
#   RH_2_1_N                        ('time', 'RH_2_1_level')                                 (122736, 1)                1
#   RH_2_1_QC                       ('time', 'RH_2_1_level')                                 (122736, 1)                1
#   RH_2_1_SE                       ('time', 'RH_2_1_level')                                 (122736, 1)                %
#   SG_1_1                          ('time', 'SG_1_1_level')                                 (122736, 1)                1
#   SG_1_1_N                        ('time', 'SG_1_1_level')                                 (122736, 1)                1
#   SG_1_1_SE                       ('time', 'SG_1_1_level')                                 (122736, 1)                1
#   SG_2_1                          ('time', 'SG_2_1_level')                                 (122736, 1)                1
#   SG_2_1_N                        ('time', 'SG_2_1_level')                                 (122736, 1)                1
#   SG_2_1_SE                       ('time', 'SG_2_1_level')                                 (122736, 1)                1
#   SG_3_1                          ('time', 'SG_3_1_level')                                 (122736, 1)                1
#   SG_3_1_N                        ('time', 'SG_3_1_level')                                 (122736, 1)                1
#   SG_3_1_SE                       ('time', 'SG_3_1_level')                                 (122736, 1)                1
#   SG_4_1                          ('time', 'SG_4_1_level')                                 (122736, 1)                1
#   SG_4_1_N                        ('time', 'SG_4_1_level')                                 (122736, 1)                1
#   SG_4_1_SE                       ('time', 'SG_4_1_level')                                 (122736, 1)                1
#   SWC                             ('time', 'soil_layer')                                   (122736, 6)                %
#   SWC_1_1                         ('time', 'SWC_1_1_level')                                (122736, 1)                %
#   SWC_1_1_N                       ('time', 'SWC_1_1_level')                                (122736, 1)                1
#   SWC_1_1_QC                      ('time', 'SWC_1_1_level')                                (122736, 1)                1
#   SWC_1_1_SE                      ('time', 'SWC_1_1_level')                                (122736, 1)                %
#   SWC_1_2                         ('time', 'SWC_1_2_level')                                (122736, 1)                %
#   SWC_1_2_N                       ('time', 'SWC_1_2_level')                                (122736, 1)                1
#   SWC_1_2_QC                      ('time', 'SWC_1_2_level')                                (122736, 1)                1
#   SWC_1_2_SE                      ('time', 'SWC_1_2_level')                                (122736, 1)                %
#   SWC_1_3                         ('time', 'SWC_1_3_level')                                (122736, 1)                %
#   SWC_1_3_N                       ('time', 'SWC_1_3_level')                                (122736, 1)                1
#   SWC_1_3_QC                      ('time', 'SWC_1_3_level')                                (122736, 1)                1
#   SWC_1_3_SE                      ('time', 'SWC_1_3_level')                                (122736, 1)                %
#   SWC_1_4                         ('time', 'SWC_1_4_level')                                (122736, 1)                %
#   SWC_1_4_N                       ('time', 'SWC_1_4_level')                                (122736, 1)                1
#   SWC_1_4_QC                      ('time', 'SWC_1_4_level')                                (122736, 1)                1
#   SWC_1_4_SE                      ('time', 'SWC_1_4_level')                                (122736, 1)                %
#   SWC_1_5                         ('time', 'SWC_1_5_level')                                (122736, 1)                %
#   SWC_1_5_N                       ('time', 'SWC_1_5_level')                                (122736, 1)                1
#   SWC_1_5_QC                      ('time', 'SWC_1_5_level')                                (122736, 1)                1
#   SWC_1_5_SE                      ('time', 'SWC_1_5_level')                                (122736, 1)                %
#   SWC_2_1                         ('time', 'SWC_2_1_level')                                (122736, 1)                %
#   SWC_2_1_N                       ('time', 'SWC_2_1_level')                                (122736, 1)                1
#   SWC_2_1_QC                      ('time', 'SWC_2_1_level')                                (122736, 1)                1
#   SWC_2_1_SE                      ('time', 'SWC_2_1_level')                                (122736, 1)                %
#   SWC_2_2                         ('time', 'SWC_2_2_level')                                (122736, 1)                %
#   SWC_2_2_N                       ('time', 'SWC_2_2_level')                                (122736, 1)                1
#   SWC_2_2_QC                      ('time', 'SWC_2_2_level')                                (122736, 1)                1
#   SWC_2_2_SE                      ('time', 'SWC_2_2_level')                                (122736, 1)                %
#   SWC_2_3                         ('time', 'SWC_2_3_level')                                (122736, 1)                %
#   SWC_2_3_N                       ('time', 'SWC_2_3_level')                                (122736, 1)                1
#   SWC_2_3_QC                      ('time', 'SWC_2_3_level')                                (122736, 1)                1
#   SWC_2_3_SE                      ('time', 'SWC_2_3_level')                                (122736, 1)                %
#   SWC_2_4                         ('time', 'SWC_2_4_level')                                (122736, 1)                %
#   SWC_2_4_N                       ('time', 'SWC_2_4_level')                                (122736, 1)                1
#   SWC_2_4_QC                      ('time', 'SWC_2_4_level')                                (122736, 1)                1
#   SWC_2_4_SE                      ('time', 'SWC_2_4_level')                                (122736, 1)                %
#   SWC_2_5                         ('time', 'SWC_2_5_level')                                (122736, 1)                %
#   SWC_2_5_N                       ('time', 'SWC_2_5_level')                                (122736, 1)                1
#   SWC_2_5_QC                      ('time', 'SWC_2_5_level')                                (122736, 1)                1
#   SWC_2_5_SE                      ('time', 'SWC_2_5_level')                                (122736, 1)                %
#   SWC_3_1                         ('time', 'SWC_3_1_level')                                (122736, 1)                %
#   SWC_3_1_N                       ('time', 'SWC_3_1_level')                                (122736, 1)                1
#   SWC_3_1_QC                      ('time', 'SWC_3_1_level')                                (122736, 1)                1
#   SWC_3_1_SE                      ('time', 'SWC_3_1_level')                                (122736, 1)                %
#   SWC_3_2                         ('time', 'SWC_3_2_level')                                (122736, 1)                %
#   SWC_3_2_N                       ('time', 'SWC_3_2_level')                                (122736, 1)                1
#   SWC_3_2_QC                      ('time', 'SWC_3_2_level')                                (122736, 1)                1
#   SWC_3_2_SE                      ('time', 'SWC_3_2_level')                                (122736, 1)                %
#   SWC_3_3                         ('time', 'SWC_3_3_level')                                (122736, 1)                %
#   SWC_3_3_N                       ('time', 'SWC_3_3_level')                                (122736, 1)                1
#   SWC_3_3_QC                      ('time', 'SWC_3_3_level')                                (122736, 1)                1
#   SWC_3_3_SE                      ('time', 'SWC_3_3_level')                                (122736, 1)                %
#   SWC_3_4                         ('time', 'SWC_3_4_level')                                (122736, 1)                %
#   SWC_3_4_N                       ('time', 'SWC_3_4_level')                                (122736, 1)                1
#   SWC_3_4_QC                      ('time', 'SWC_3_4_level')                                (122736, 1)                1
#   SWC_3_4_SE                      ('time', 'SWC_3_4_level')                                (122736, 1)                %
#   SWC_3_5                         ('time', 'SWC_3_5_level')                                (122736, 1)                %
#   SWC_3_5_N                       ('time', 'SWC_3_5_level')                                (122736, 1)                1
#   SWC_3_5_QC                      ('time', 'SWC_3_5_level')                                (122736, 1)                1
#   SWC_3_5_SE                      ('time', 'SWC_3_5_level')                                (122736, 1)                %
#   SWC_4_1                         ('time', 'SWC_4_1_level')                                (122736, 1)                %
#   SWC_4_1_N                       ('time', 'SWC_4_1_level')                                (122736, 1)                1
#   SWC_4_1_QC                      ('time', 'SWC_4_1_level')                                (122736, 1)                1
#   SWC_4_1_SE                      ('time', 'SWC_4_1_level')                                (122736, 1)                %
#   SWC_4_2                         ('time', 'SWC_4_2_level')                                (122736, 1)                %
#   SWC_4_2_N                       ('time', 'SWC_4_2_level')                                (122736, 1)                1
#   SWC_4_2_QC                      ('time', 'SWC_4_2_level')                                (122736, 1)                1
#   SWC_4_2_SE                      ('time', 'SWC_4_2_level')                                (122736, 1)                %
#   SWC_4_3                         ('time', 'SWC_4_3_level')                                (122736, 1)                %
#   SWC_4_3_N                       ('time', 'SWC_4_3_level')                                (122736, 1)                1
#   SWC_4_3_QC                      ('time', 'SWC_4_3_level')                                (122736, 1)                1
#   SWC_4_3_SE                      ('time', 'SWC_4_3_level')                                (122736, 1)                %
#   SWC_4_4                         ('time', 'SWC_4_4_level')                                (122736, 1)                %
#   SWC_4_4_N                       ('time', 'SWC_4_4_level')                                (122736, 1)                1
#   SWC_4_4_QC                      ('time', 'SWC_4_4_level')                                (122736, 1)                1
#   SWC_4_4_SE                      ('time', 'SWC_4_4_level')                                (122736, 1)                %
#   SWC_QC                          ('time', 'soil_layer')                                   (122736, 6)                1
#   SWC_obs                         ('time', 'SWC_obs_level')                                (122736, 5)                %
#   SWC_obs_N                       ('time', 'SWC_obs_level')                                (122736, 5)                1
#   SWC_obs_SD                      ('time', 'SWC_obs_level')                                (122736, 5)                %
#   SW_IN_1_1                       ('time', 'SW_IN_1_1_level')                              (122736, 2)                W m-2
#   SW_IN_1_1_N                     ('time', 'SW_IN_1_1_level')                              (122736, 2)                1
#   SW_IN_1_1_QC                    ('time', 'SW_IN_1_1_level')                              (122736, 2)                1
#   SW_IN_1_1_SE                    ('time', 'SW_IN_1_1_level')                              (122736, 2)                W m-2
#   SW_IN_2_1                       ('time', 'SW_IN_2_1_level')                              (122736, 1)                W m-2
#   SW_IN_2_1_N                     ('time', 'SW_IN_2_1_level')                              (122736, 1)                1
#   SW_IN_2_1_QC                    ('time', 'SW_IN_2_1_level')                              (122736, 1)                1
#   SW_IN_2_1_SE                    ('time', 'SW_IN_2_1_level')                              (122736, 1)                W m-2
#   SW_OUT_1_1                      ('time', 'SW_OUT_1_1_level')                             (122736, 1)                W m-2
#   SW_OUT_1_1_N                    ('time', 'SW_OUT_1_1_level')                             (122736, 1)                1
#   SW_OUT_1_1_QC                   ('time', 'SW_OUT_1_1_level')                             (122736, 1)                1
#   SW_OUT_1_1_SE                   ('time', 'SW_OUT_1_1_level')                             (122736, 1)                W m-2
#   TA                              ('time', 'TA_level')                                     (122736, 9)                degC
#   TA_1_1                          ('time', 'TA_1_1_level')                                 (122736, 2)                degC
#   TA_1_1_N                        ('time', 'TA_1_1_level')                                 (122736, 2)                1
#   TA_1_1_QC                       ('time', 'TA_1_1_level')                                 (122736, 2)                1
#   TA_1_1_SE                       ('time', 'TA_1_1_level')                                 (122736, 2)                degC
#   TA_1_2                          ('time', 'TA_1_2_level')                                 (122736, 2)                degC
#   TA_1_2_N                        ('time', 'TA_1_2_level')                                 (122736, 2)                1
#   TA_1_2_QC                       ('time', 'TA_1_2_level')                                 (122736, 2)                1
#   TA_1_2_SE                       ('time', 'TA_1_2_level')                                 (122736, 2)                degC
#   TA_2_1                          ('time', 'TA_2_1_level')                                 (122736, 1)                degC
#   TA_2_10                         ('time', 'TA_2_10_level')                                (122736, 1)                degC
#   TA_2_10_N                       ('time', 'TA_2_10_level')                                (122736, 1)                1
#   TA_2_10_QC                      ('time', 'TA_2_10_level')                                (122736, 1)                1
#   TA_2_10_SE                      ('time', 'TA_2_10_level')                                (122736, 1)                degC
#   TA_2_11                         ('time', 'TA_2_11_level')                                (122736, 1)                degC
#   TA_2_11_N                       ('time', 'TA_2_11_level')                                (122736, 1)                1
#   TA_2_11_QC                      ('time', 'TA_2_11_level')                                (122736, 1)                1
#   TA_2_11_SE                      ('time', 'TA_2_11_level')                                (122736, 1)                degC
#   TA_2_12                         ('time', 'TA_2_12_level')                                (122736, 1)                degC
#   TA_2_12_N                       ('time', 'TA_2_12_level')                                (122736, 1)                1
#   TA_2_12_QC                      ('time', 'TA_2_12_level')                                (122736, 1)                1
#   TA_2_12_SE                      ('time', 'TA_2_12_level')                                (122736, 1)                degC
#   TA_2_13                         ('time', 'TA_2_13_level')                                (122736, 1)                degC
#   TA_2_13_N                       ('time', 'TA_2_13_level')                                (122736, 1)                1
#   TA_2_13_QC                      ('time', 'TA_2_13_level')                                (122736, 1)                1
#   TA_2_13_SE                      ('time', 'TA_2_13_level')                                (122736, 1)                degC
#   TA_2_14                         ('time', 'TA_2_14_level')                                (122736, 1)                degC
#   TA_2_14_N                       ('time', 'TA_2_14_level')                                (122736, 1)                1
#   TA_2_14_QC                      ('time', 'TA_2_14_level')                                (122736, 1)                1
#   TA_2_14_SE                      ('time', 'TA_2_14_level')                                (122736, 1)                degC
#   TA_2_15                         ('time', 'TA_2_15_level')                                (122736, 1)                degC
#   TA_2_15_N                       ('time', 'TA_2_15_level')                                (122736, 1)                1
#   TA_2_15_QC                      ('time', 'TA_2_15_level')                                (122736, 1)                1
#   TA_2_15_SE                      ('time', 'TA_2_15_level')                                (122736, 1)                degC
#   TA_2_16                         ('time', 'TA_2_16_level')                                (122736, 1)                degC
#   TA_2_16_N                       ('time', 'TA_2_16_level')                                (122736, 1)                1
#   TA_2_16_QC                      ('time', 'TA_2_16_level')                                (122736, 1)                1
#   TA_2_16_SE                      ('time', 'TA_2_16_level')                                (122736, 1)                degC
#   TA_2_1_N                        ('time', 'TA_2_1_level')                                 (122736, 1)                1
#   TA_2_1_QC                       ('time', 'TA_2_1_level')                                 (122736, 1)                1
#   TA_2_1_SE                       ('time', 'TA_2_1_level')                                 (122736, 1)                degC
#   TA_2_2                          ('time', 'TA_2_2_level')                                 (122736, 1)                degC
#   TA_2_2_N                        ('time', 'TA_2_2_level')                                 (122736, 1)                1
#   TA_2_2_QC                       ('time', 'TA_2_2_level')                                 (122736, 1)                1
#   TA_2_2_SE                       ('time', 'TA_2_2_level')                                 (122736, 1)                degC
#   TA_2_3                          ('time', 'TA_2_3_level')                                 (122736, 1)                degC
#   TA_2_3_N                        ('time', 'TA_2_3_level')                                 (122736, 1)                1
#   TA_2_3_QC                       ('time', 'TA_2_3_level')                                 (122736, 1)                1
#   TA_2_3_SE                       ('time', 'TA_2_3_level')                                 (122736, 1)                degC
#   TA_2_4                          ('time', 'TA_2_4_level')                                 (122736, 1)                degC
#   TA_2_4_N                        ('time', 'TA_2_4_level')                                 (122736, 1)                1
#   TA_2_4_QC                       ('time', 'TA_2_4_level')                                 (122736, 1)                1
#   TA_2_4_SE                       ('time', 'TA_2_4_level')                                 (122736, 1)                degC
#   TA_2_5                          ('time', 'TA_2_5_level')                                 (122736, 1)                degC
#   TA_2_5_N                        ('time', 'TA_2_5_level')                                 (122736, 1)                1
#   TA_2_5_QC                       ('time', 'TA_2_5_level')                                 (122736, 1)                1
#   TA_2_5_SE                       ('time', 'TA_2_5_level')                                 (122736, 1)                degC
#   TA_2_6                          ('time', 'TA_2_6_level')                                 (122736, 1)                degC
#   TA_2_6_N                        ('time', 'TA_2_6_level')                                 (122736, 1)                1
#   TA_2_6_QC                       ('time', 'TA_2_6_level')                                 (122736, 1)                1
#   TA_2_6_SE                       ('time', 'TA_2_6_level')                                 (122736, 1)                degC
#   TA_2_7                          ('time', 'TA_2_7_level')                                 (122736, 1)                degC
#   TA_2_7_N                        ('time', 'TA_2_7_level')                                 (122736, 1)                1
#   TA_2_7_QC                       ('time', 'TA_2_7_level')                                 (122736, 1)                1
#   TA_2_7_SE                       ('time', 'TA_2_7_level')                                 (122736, 1)                degC
#   TA_2_8                          ('time', 'TA_2_8_level')                                 (122736, 1)                degC
#   TA_2_8_N                        ('time', 'TA_2_8_level')                                 (122736, 1)                1
#   TA_2_8_QC                       ('time', 'TA_2_8_level')                                 (122736, 1)                1
#   TA_2_8_SE                       ('time', 'TA_2_8_level')                                 (122736, 1)                degC
#   TA_2_9                          ('time', 'TA_2_9_level')                                 (122736, 1)                degC
#   TA_2_9_N                        ('time', 'TA_2_9_level')                                 (122736, 1)                1
#   TA_2_9_QC                       ('time', 'TA_2_9_level')                                 (122736, 1)                1
#   TA_2_9_SE                       ('time', 'TA_2_9_level')                                 (122736, 1)                degC
#   TA_4_1                          ('time', 'TA_4_1_level')                                 (122736, 1)                degC
#   TA_4_1_N                        ('time', 'TA_4_1_level')                                 (122736, 1)                1
#   TA_4_1_QC                       ('time', 'TA_4_1_level')                                 (122736, 1)                1
#   TA_4_1_SE                       ('time', 'TA_4_1_level')                                 (122736, 1)                degC
#   TA_5_1                          ('time', 'TA_5_1_level')                                 (122736, 1)                degC
#   TA_5_1_N                        ('time', 'TA_5_1_level')                                 (122736, 1)                1
#   TA_5_1_QC                       ('time', 'TA_5_1_level')                                 (122736, 1)                1
#   TA_5_1_SE                       ('time', 'TA_5_1_level')                                 (122736, 1)                degC
#   TS                              ('time', 'soil_layer')                                   (122736, 6)                degC
#   TS_1_1                          ('time', 'TS_1_1_level')                                 (122736, 1)                degC
#   TS_1_1_N                        ('time', 'TS_1_1_level')                                 (122736, 1)                1
#   TS_1_1_QC                       ('time', 'TS_1_1_level')                                 (122736, 1)                1
#   TS_1_1_SE                       ('time', 'TS_1_1_level')                                 (122736, 1)                degC
#   TS_1_2                          ('time', 'TS_1_2_level')                                 (122736, 1)                degC
#   TS_1_2_N                        ('time', 'TS_1_2_level')                                 (122736, 1)                1
#   TS_1_2_QC                       ('time', 'TS_1_2_level')                                 (122736, 1)                1
#   TS_1_2_SE                       ('time', 'TS_1_2_level')                                 (122736, 1)                degC
#   TS_1_3                          ('time', 'TS_1_3_level')                                 (122736, 1)                degC
#   TS_1_3_N                        ('time', 'TS_1_3_level')                                 (122736, 1)                1
#   TS_1_3_QC                       ('time', 'TS_1_3_level')                                 (122736, 1)                1
#   TS_1_3_SE                       ('time', 'TS_1_3_level')                                 (122736, 1)                degC
#   TS_1_4                          ('time', 'TS_1_4_level')                                 (122736, 1)                degC
#   TS_1_4_N                        ('time', 'TS_1_4_level')                                 (122736, 1)                1
#   TS_1_4_QC                       ('time', 'TS_1_4_level')                                 (122736, 1)                1
#   TS_1_4_SE                       ('time', 'TS_1_4_level')                                 (122736, 1)                degC
#   TS_1_5                          ('time', 'TS_1_5_level')                                 (122736, 1)                degC
#   TS_1_5_N                        ('time', 'TS_1_5_level')                                 (122736, 1)                1
#   TS_1_5_QC                       ('time', 'TS_1_5_level')                                 (122736, 1)                1
#   TS_1_5_SE                       ('time', 'TS_1_5_level')                                 (122736, 1)                degC
#   TS_1_6                          ('time', 'TS_1_6_level')                                 (122736, 1)                degC
#   TS_1_6_N                        ('time', 'TS_1_6_level')                                 (122736, 1)                1
#   TS_1_6_QC                       ('time', 'TS_1_6_level')                                 (122736, 1)                1
#   TS_1_6_SE                       ('time', 'TS_1_6_level')                                 (122736, 1)                degC
#   TS_2_1                          ('time', 'TS_2_1_level')                                 (122736, 1)                degC
#   TS_2_1_N                        ('time', 'TS_2_1_level')                                 (122736, 1)                1
#   TS_2_1_QC                       ('time', 'TS_2_1_level')                                 (122736, 1)                1
#   TS_2_1_SE                       ('time', 'TS_2_1_level')                                 (122736, 1)                degC
#   TS_2_2                          ('time', 'TS_2_2_level')                                 (122736, 1)                degC
#   TS_2_2_N                        ('time', 'TS_2_2_level')                                 (122736, 1)                1
# ...
#   LW_IN_raw                       ('time',)                                                (122736,)                  W m-2
#   MISSING_LEV_ID_TA               ('time',)                                                (122736,)                  1
#   MISSING_LEV_N_CO2               ('time',)                                                (122736,)                  1
#   MISSING_LEV_N_H2O               ('time',)                                                (122736,)                  1
#   MISSING_LEV_N_TA                ('time',)                                                (122736,)                  1
#   MO_LENGTH                       ('time',)                                                (122736,)                  1
#   NEE_CUT_REF_RANDUNC_METHOD      ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_CUT_REF_RANDUNC_N           ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_CUT_USTAR50_RANDUNC_METHOD  ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_CUT_USTAR50_RANDUNC_N       ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_DATA_FLAG                   ('time',)                                                (122736,)                  1
#   NEE_OOR_FLAG                    ('time',)                                                (122736,)                  1
#   NEE_OUTLYING_FLAG               ('time',)                                                (122736,)                  1
#   NEE_UNCLEANED                   ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_VUT_REF_RANDUNC_METHOD      ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_VUT_REF_RANDUNC_N           ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_VUT_USTAR50_RANDUNC_METHOD  ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_VUT_USTAR50_RANDUNC_N       ('time',)                                                (122736,)                  umol m-2 s-1
#   NEE_raw                         ('time',)                                                (122736,)                  umol m-2 s-1
#   NIGHT                           ('time',)                                                (122736,)                  1
#   PA_ERA                          ('time',)                                                (122736,)                  kPa
#   PA_F                            ('time',)                                                (122736,)                  kPa
#   PA_F_QC                         ('time',)                                                (122736,)                  1
#   PBLH                            ('time',)                                                (122736,)                  1
#   PPFD_BC_IN_N_raw                ('time',)                                                (122736,)                  1
#   PPFD_BC_IN_SD                   ('time',)                                                (122736,)                  1
#   PPFD_BC_IN_raw                  ('time',)                                                (122736,)                  1
#   P_ERA                           ('time',)                                                (122736,)                  mm
#   P_F                             ('time',)                                                (122736,)                  mm
#   P_F_QC                          ('time',)                                                (122736,)                  1
#   SA_DIAG_FLAG                    ('time',)                                                (122736,)                  1
#   SC                              ('time',)                                                (122736,)                  umol m-2 s-1
#   SC_1P                           ('time',)                                                (122736,)                  umol m-2 s-1
#   SC_FLAG                         ('time',)                                                (122736,)                  1
#   SC_OOR_FLAG                     ('time',)                                                (122736,)                  1
#   SC_UNC                          ('time',)                                                (122736,)                  umol m-2 s-1
#   SC_UNCLEANED                    ('time',)                                                (122736,)                  umol m-2 s-1
#   SC_UNC_FLAG                     ('time',)                                                (122736,)                  1
#   SH                              ('time',)                                                (122736,)                  1
#   SH_1P                           ('time',)                                                (122736,)                  1
#   SH_FLAG                         ('time',)                                                (122736,)                  1
#   SH_OOR_FLAG                     ('time',)                                                (122736,)                  1
#   SH_UNC                          ('time',)                                                (122736,)                  1
#   SH_UNCLEANED                    ('time',)                                                (122736,)                  1
#   SH_UNC_FLAG                     ('time',)                                                (122736,)                  1
#   SLE                             ('time',)                                                (122736,)                  1
#   SLE_1P                          ('time',)                                                (122736,)                  1
#   SLE_FLAG                        ('time',)                                                (122736,)                  1
#   SLE_OOR_FLAG                    ('time',)                                                (122736,)                  1
#   SLE_UNC                         ('time',)                                                (122736,)                  1
#   SLE_UNCLEANED                   ('time',)                                                (122736,)                  1
#   SLE_UNC_FLAG                    ('time',)                                                (122736,)                  1
#   SW_IN_ERA                       ('time',)                                                (122736,)                  W m-2
#   SW_IN_F                         ('time',)                                                (122736,)                  W m-2
#   SW_IN_F_MDS                     ('time',)                                                (122736,)                  W m-2
#   SW_IN_F_MDS_QC                  ('time',)                                                (122736,)                  1
#   SW_IN_F_QC                      ('time',)                                                (122736,)                  1
#   SW_IN_POT                       ('time',)                                                (122736,)                  W m-2
#   SW_IN_raw                       ('time',)                                                (122736,)                  W m-2
#   TAU                             ('time',)                                                (122736,)                  1
#   TAU_DATA_FLAG                   ('time',)                                                (122736,)                  1
#   TAU_FMR_FLAG                    ('time',)                                                (122736,)                  1
#   TAU_FMR_STAT                    ('time',)                                                (122736,)                  1
#   TAU_LGD_FLAG                    ('time',)                                                (122736,)                  1
#   TAU_LGD_STAT                    ('time',)                                                (122736,)                  1
#   TAU_LSR_FLAG                    ('time',)                                                (122736,)                  1
#   TAU_LSR_STAT                    ('time',)                                                (122736,)                  1
#   TAU_M98_FLAG                    ('time',)                                                (122736,)                  1
#   TAU_M98_STAT                    ('time',)                                                (122736,)                  1
#   TAU_OOR_FLAG                    ('time',)                                                (122736,)                  1
#   TAU_OUTLYING_FLAG               ('time',)                                                (122736,)                  1
#   TAU_SSITC_TEST                  ('time',)                                                (122736,)                  1
#   TAU_UNCLEANED                   ('time',)                                                (122736,)                  1
#   TA_ERA                          ('time',)                                                (122736,)                  degC
#   TA_F                            ('time',)                                                (122736,)                  degC
#   TA_F_MDS                        ('time',)                                                (122736,)                  degC
#   TA_F_MDS_QC                     ('time',)                                                (122736,)                  1
#   TA_F_QC                         ('time',)                                                (122736,)                  1
#   TA_raw                          ('time',)                                                (122736,)                  degC
#   T_SONIC                         ('time',)                                                (122736,)                  1
#   T_SONIC_AL1_FLAG                ('time',)                                                (122736,)                  1
#   T_SONIC_AL1_STAT                ('time',)                                                (122736,)                  1
#   T_SONIC_DDI_FLAG                ('time',)                                                (122736,)                  1
#   T_SONIC_DDI_STAT                ('time',)                                                (122736,)                  1
#   T_SONIC_DIP_FLAG                ('time',)                                                (122736,)                  1
#   T_SONIC_DIP_STAT                ('time',)                                                (122736,)                  1
#   T_SONIC_HD10_FLAG               ('time',)                                                (122736,)                  1
#   T_SONIC_HD10_STAT               ('time',)                                                (122736,)                  1
#   T_SONIC_HD5_FLAG                ('time',)                                                (122736,)                  1
#   T_SONIC_HD5_STAT                ('time',)                                                (122736,)                  1
#   T_SONIC_HF10_FLAG               ('time',)                                                (122736,)                  1
#   T_SONIC_HF10_STAT               ('time',)                                                (122736,)                  1
#   T_SONIC_HF5_FLAG                ('time',)                                                (122736,)                  1
#   T_SONIC_HF5_STAT                ('time',)                                                (122736,)                  1
#   T_SONIC_KID_FLAG                ('time',)                                                (122736,)                  1
#   T_SONIC_KID_STAT                ('time',)                                                (122736,)                  1
#   T_SONIC_SIGMA                   ('time',)                                                (122736,)                  1
#   U_SIGMA                         ('time',)                                                (122736,)                  1
#   VPD_ERA                         ('time',)                                                (122736,)                  hPa
#   VPD_F                           ('time',)                                                (122736,)                  hPa
#   VPD_F_MDS                       ('time',)                                                (122736,)                  hPa
#   VPD_F_MDS_QC                    ('time',)                                                (122736,)                  1
#   VPD_F_QC                        ('time',)                                                (122736,)                  1
#   VPD_raw                         ('time',)                                                (122736,)                  hPa
#   V_SIGMA                         ('time',)                                                (122736,)                  1
#   WSECT_FLAG                      ('time',)                                                (122736,)                  1
#   WS_ERA                          ('time',)                                                (122736,)                  m s-1
#   WS_F                            ('time',)                                                (122736,)                  m s-1
#   WS_F_QC                         ('time',)                                                (122736,)                  1
#   WTD_N_raw                       ('time',)                                                (122736,)                  m
#   WTD_SD                          ('time',)                                                (122736,)                  m
#   WTD_raw                         ('time',)                                                (122736,)                  m
#   W_AL1_FLAG                      ('time',)                                                (122736,)                  1
#   W_AL1_STAT                      ('time',)                                                (122736,)                  1
#   W_DDI_FLAG                      ('time',)                                                (122736,)                  1
#   W_DDI_STAT                      ('time',)                                                (122736,)                  1
#   W_DIP_FLAG                      ('time',)                                                (122736,)                  1
#   W_DIP_STAT                      ('time',)                                                (122736,)                  1
#   W_HD10_FLAG                     ('time',)                                                (122736,)                  1
#   W_HD10_STAT                     ('time',)                                                (122736,)                  1
#   W_HD5_FLAG                      ('time',)                                                (122736,)                  1
#   W_HD5_STAT                      ('time',)                                                (122736,)                  1
#   W_HF10_FLAG                     ('time',)                                                (122736,)                  1
#   W_HF10_STAT                     ('time',)                                                (122736,)                  1
#   W_HF5_FLAG                      ('time',)                                                (122736,)                  1
#   W_HF5_STAT                      ('time',)                                                (122736,)                  1
#   W_KID_FLAG                      ('time',)                                                (122736,)                  1
#   W_KID_STAT                      ('time',)                                                (122736,)                  1
#   W_SIGMA                         ('time',)                                                (122736,)                  1
#   ZL                              ('time',)                                                (122736,)                  1
#   temporal_resolution             ()                                                       ()

# %% [markdown]
# ## 7 · Data passport
#
# Every chunk read above was aggregated into a per-client session on the
# server. Asking for the **passport** closes the session and returns an
# RO-Crate JSON-LD record of exactly what this notebook accessed — groups,
# arrays, byte counts, access date, citation, licence, integrity hash.

# %%
import requests

r = requests.get(f"{STORE}/session/passport").json()
passport = r["passport"]
rec = passport["@graph"][1]
print("accessed:", rec["accessedGroups"], "on", rec["dateAccessed"])
print("arrays  :", len(rec["accessedArrays"]), "| bytes:", rec["totalBytesServed"])
print("sha256  :", rec["passportSha256"][:32], "…")
with open("explore_zarr_passport.json", "w") as f:
    json.dump(passport, f, indent=2)
print("saved → explore_zarr_passport.json")
# Out:
# accessed: ['SE-Svb', 'SE-Svb/fluxnet_dd', 'SE-Svb/fluxnet_mm', 'SE-Svb/fluxnet_ww', 'SE-Svb/fluxnet_yy', 'SE-Svb/meteosens'] on 2026-08-17T17:15:15Z
# arrays  : 204 | bytes: 88929325
# sha256  : 865fbe1248cc6f9777a0b36d28bb4592 …
# saved → explore_zarr_passport.json
